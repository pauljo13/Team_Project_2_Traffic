# %%
import cv2
import json
import numpy as np
import random
import os
import shutil

# %%
def copy_files_to_destination(names, source_dir, dest_dir, extension):
    os.chdir(source_dir)
    for name in names:
        file_name = name + extension
        shutil.copy2(file_name, dest_dir)

def toy_data_loed(json_url, image_url):
    filenames_json = os.listdir(json_url)
    filenames_img = os.listdir(image_url)

    json_names = [os.path.splitext(filename)[0] for filename in filenames_json]
    img_names = [os.path.splitext(filename)[0] for filename in filenames_img]

    names_list = list(set(json_names) & set(img_names))
    selected_filenames = random.sample(names_list, 10)

    json_dest = '/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/Team_Project_2_Traffic/toy/toy_data/json'
    img_dest = '/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/Team_Project_2_Traffic/toy/toy_data/image'
    
    copy_files_to_destination(selected_filenames, json_url, json_dest, '.json')
    copy_files_to_destination(selected_filenames, image_url, img_dest, '.jpg')

    return print('ok')

# %%
filenames = os.listdir('/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/라벨링데이터/VL1/CCTV/야간/맑음/실증')

# %%
for filename in filenames:
        img_names.append(filename[:-4])
img_names
# Out:
# ['S000569_054_0315_C_N_F_0.',
#  'S000514_010_0024_C_N_F_0.',
#  'S000568_045_0063_C_N_F_0.',
#  'S001763_008_0018_C_N_F_0.',
#  'C000003_045_0050_C_N_F_0.',
#  'S001461_023_0270_C_N_F_0.',
#  'S000567_042_0216_C_N_F_0.',
#  'S000245_027_0160_C_N_F_0.',
#  'S001680_009_0168_C_N_F_0.',
#  'C000473_015_0320_C_N_F_0.',
#  'C002653_000_0140_C_N_F_0.',
#  'C000884_004_0048_C_N_F_0.',
#  'C000161_080_0120_C_N_F_0.',
#  'S001140_020_0224_C_N_F_0.',
#  'S001219_017_0080_C_N_F_0.',
#  'S000175_031_0147_C_N_F_0.',
#  'S001235_009_0120_C_N_F_0.',
#  'S002126_006_0096_C_N_F_0.',
#  'C000883_071_0156_C_N_F_0.',
#  'S001757_044_0336_C_N_F_0.',
#  'T005035_070_0144_C_N_F_0.',
#  'C000174_059_0220_C_N_F_0.',
#  'S002258_015_0120_C_N_F_0.',
#  'C000643_003_0294_C_N_F_0.',
#  'S000341_015_0182_C_N_F_0.',
#  'C001340_002_0048_C_N_F_0.',
#  'S002108_012_0180_C_N_F_0.',
#  'S002109_010_0090_C_N_F_0.',
#  'C000883_072_0048_C_N_F_0.',
#  'S001058_013_0380_C_N_F_0.',
#  'S000959_000_0168_C_N_F_0.',
# ...

# %%
selected_filenames = random.sample(img_names, 20)

print(selected_filenames)
# Out:
# ['S001531_009_0228_C_N_F_0.', 'S000655_024_0240_C_N_F_', 'S001683_019_0130_C_N_F_', 'C000298_038_0216_C_N_F_0', 'S000290_011_0230_C_N_F_', 'M302181_002_0030_C_N_F_', 'C000158_110_0224_C_N_F_', 'S001682_020_0390_C_N_F_0.', 'S001538_004_0264_C_N_F_', 'C001338_020_0054_C_N_F_', 'S001788_003_0196_C_N_F_0', 'S000210_030_0060_C_N_F_0.', 'S000059_007_0144_C_N_F_', 'S000245_003_0045_C_N_F_0.', 'S000568_032_0189_C_N_F_', 'S000548_036_0352_C_N_F_', 'M231618_000_0240_C_N_F_0.', 'M241744_003_0090_C_N_F_0.', 'S001205_008_0056_C_N_F_0.', 'C000733_047_0017_C_N_F_']

# %%
def copy_file(base_dir,data_dir, name_list):
  os.chdir(base_dir)
  for name in name_list:
    name_jpg = name+'.jpg'
    shutil.copy2(name_jpg,data_dir)

  return len(os.listdir(data_dir))

# %%
json_url_list = ['/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/라벨링데이터/VL1/CCTV/야간/맑음/실증',
'/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/라벨링데이터/VL1/CCTV/야간/우천/실증',
'/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/라벨링데이터/VL1/CCTV/주간/맑음/실증',
'/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/라벨링데이터/VL1/CCTV/주간/우천/실증'
]
img_url_list = ['/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/원천데이터/VS1/CCTV/야간/맑음/실증',
'/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/원천데이터/VS1/CCTV/야간/우천/실증',
'/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/원천데이터/VS1/CCTV/주간/맑음/실증',
'/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/원천데이터/VS1/CCTV/주간/우천/실증']

url_list = []
for i in range(0,4):
    url_list.append([json_url_list[i],img_url_list[i]])

url_list
# Out:
# [['/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/라벨링데이터/VL1/CCTV/야간/맑음/실증',
#   '/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/원천데이터/VS1/CCTV/야간/맑음/실증'],
#  ['/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/라벨링데이터/VL1/CCTV/야간/우천/실증',
#   '/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/원천데이터/VS1/CCTV/야간/우천/실증'],
#  ['/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/라벨링데이터/VL1/CCTV/주간/맑음/실증',
#   '/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/원천데이터/VS1/CCTV/주간/맑음/실증'],
#  ['/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/라벨링데이터/VL1/CCTV/주간/우천/실증',
#   '/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/120.개인형 이동장치 안전 데이터/01.데이터/2.Validation/원천데이터/VS1/CCTV/주간/우천/실증']]

# %%
for j,i in url_list:
    toy_data_loed(j,i)
# Out:
# ok
# ok
# ok
# ok

# %%
filenames_image = os.listdir('/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/Team_Project_2_Traffic/toy/toy_data/image')
filenames_json = os.listdir('/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/Team_Project_2_Traffic/toy/toy_data/json')
filenames_image.remove('.DS_Store')
print(len(filenames_image),
len(filenames_json))
# Out:
# 40 40

# %%
filenames_image
# Out:
# ['S002185_003_0228_C_D_F_0.jpg',
#  'S000031_014_0273_C_D_R_0.jpg',
#  'C005728_000_0525_C_N_R_0.jpg',
#  'S000898_019_0200_C_N_R_0.jpg',
#  'S001784_020_0234_C_N_R_0.jpg',
#  'S000898_019_0100_C_N_R_0.jpg',
#  'S001784_015_0080_C_N_R_0.jpg',
#  'C000191_002_0396_C_D_F_0.jpg',
#  'S002329_034_0280_C_N_R_0.jpg',
#  'S001011_004_0357_C_D_R_0.jpg',
#  'S002080_052_0224_C_N_F_0.jpg',
#  'S000211_014_0168_C_N_F_0.jpg',
#  'S000821_019_0230_C_D_F_0.jpg',
#  'C000003_037_0234_C_N_F_0.jpg',
#  'S000017_026_0294_C_D_R_0.jpg',
#  'S000826_003_0104_C_D_R_0.jpg',
#  'C000435_027_0138_C_D_F_0.jpg',
#  'S000897_003_0022_C_N_R_0.jpg',
#  'C001230_030_0066_C_D_F_0.jpg',
#  'C000014_081_0026_C_D_R_0.jpg',
#  'C000013_179_0224_C_D_R_0.jpg',
#  'C005646_000_0260_C_N_R_0.jpg',
#  'S000898_004_0110_C_N_R_0.jpg',
#  'C000069_043_0144_C_D_R_0.jpg',
#  'S000257_004_0272_C_N_F_0.jpg',
#  'S001788_024_0264_C_N_F_0.jpg',
#  'S000811_031_0045_C_D_F_0.jpg',
#  'C004226_000_0260_C_N_F_0.jpg',
# ...

# %%
filenames_json
# Out:
# ['S001580_046_0112_C_N_F_0.json',
#  'S000811_031_0045_C_D_F_0.json',
#  'S000898_019_0100_C_N_R_0.json',
#  'S002500_052_0112_C_D_F_0.json',
#  'C000069_043_0144_C_D_R_0.json',
#  'S000898_015_0198_C_N_R_0.json',
#  'C000435_027_0138_C_D_F_0.json',
#  'C000013_179_0224_C_D_R_0.json',
#  'S001784_020_0234_C_N_R_0.json',
#  'S001784_015_0080_C_N_R_0.json',
#  'S001011_004_0357_C_D_R_0.json',
#  'C000014_081_0026_C_D_R_0.json',
#  'S002350_013_0128_C_N_F_0.json',
#  'S000898_019_0200_C_N_R_0.json',
#  'C000014_062_0221_C_D_R_0.json',
#  'S000831_016_0399_C_D_R_0.json',
#  'S000821_019_0230_C_D_F_0.json',
#  'C000191_002_0396_C_D_F_0.json',
#  'S000897_003_0022_C_N_R_0.json',
#  'C005646_000_0260_C_N_R_0.json',
#  'S000017_026_0294_C_D_R_0.json',
#  'S001788_024_0264_C_N_F_0.json',
#  'S000257_004_0272_C_N_F_0.json',
#  'S000031_014_0273_C_D_R_0.json',
#  'S001761_005_0228_C_N_F_0.json',
#  'C001230_030_0066_C_D_F_0.json',
#  'S000826_003_0104_C_D_R_0.json',
# ...

# %%
import json
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.applications.vgg16 import VGG16
from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import json
import os
import cv2
import numpy as np

# 이미지와 JSON 파일의 경로
image_dir = '/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/Team_Project_2_Traffic/toy/toy_data/image'
json_dir = '/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/Team_Project_2_Traffic/toy/toy_data/json'

images = []
annotations = []

for filename in os.listdir(image_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # 이미지 파일인 경우
        image_path = os.path.join(image_dir, filename)
        json_path = os.path.join(json_dir, filename.split('.')[0] + '.json')

        # 이미지 불러오기
        image = cv2.imread(image_path)
        images.append(image)

        # JSON 라벨 불러오기
        with open(json_path, 'r') as f:
            data = json.load(f)
            
            image_info = {
                "width": data["description"]["imageWidth"],
                "height": data["description"]["imageHeight"],
            }

            env_annotations = data["annotations"]["environment"]
            pm_annotations = data["annotations"]["PM"]
            
            annotation = {
                "image_info": image_info,
                "environment": env_annotations,
                "PM": pm_annotations
            }
            annotations.append(annotation)

labels = []
for annotation in annotations:
    if annotation['environment']:
        labels.append(0)
    elif annotation['PM']:
        labels.append(1)
    else:
        labels.append(-1)  # 다른 라벨 또는 기본값을 위한 코드



# 데이터 전처리
X = np.array(images)
Y = np.array(labels)
Y = tf.keras.utils.to_categorical(Y, num_classes=2)  # 클래스가 2개라고 가정

resized_images = [cv2.resize(img, (224, 224)) for img in images]
X = np.array(resized_images) / 255.0


# 3. 모델 학습
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
x = base_model.output
x = Flatten()(x)
x = Dense(1024, activation="relu")(x)
predictions = Dense(2, activation="softmax")(x)  # 2는 분류할 클래스의 수입니다. 필요에 따라 변경해야 합니다.
model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
model.fit(X, Y, epochs=10, batch_size=32)

# 4. 위반 사항 분석
new_img_path = "/Users/bumsoojoe/Desktop/팀프로젝트2_교통법규/Team_Project_2_Traffic/toy/toy_test/C001237_008_0220_C_N_F_0.jpg"
new_img = keras.preprocessing.image.load_img(new_img_path, target_size=(224, 224))
new_img_arr = np.expand_dims(keras.preprocessing.image.img_to_array(new_img), axis=0)

# 분류 예측
predictions = model.predict(new_img_arr)

# 결과 출력
if np.argmax(predictions) == 1:  # 위반 사항을 탐지한 경우
    print("교통법규 위반 사항이 감지되었습니다.")
else:
    print("교통법규 위반 사항이 없습니다.")
# Out:
# Epoch 1/10
# 2/2 [==============================] - 8s 1s/step - loss: 1.5516 - accuracy: 0.2000
# Epoch 2/10
# 2/2 [==============================] - 7s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 3/10
# 2/2 [==============================] - 7s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 4/10
# 2/2 [==============================] - 7s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 5/10
# 2/2 [==============================] - 7s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 6/10
# 2/2 [==============================] - 7s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 7/10
# 2/2 [==============================] - 7s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 8/10
# 2/2 [==============================] - 7s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 9/10
# 2/2 [==============================] - 7s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 10/10
# ...
# 1/1 [==============================] - 0s 121ms/step
# ...

# %%
# 바운딩 박스 예측
bboxes = model.predict(new_img_arr)

# 이미지에 바운딩 박스 그리기
fig, ax = plt.subplots(1)
ax.imshow(new_img)

for box in bboxes:
    x, y, w, h = box  # 각 바운딩 박스의 좌표와 너비/높이
    rect = patches.Rectangle((x, y), w, h, linewidth=1, edgecolor='r', facecolor='none')
    ax.add_patch(rect)

plt.show()
# Out:
# 1/1 [==============================] - 0s 80ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 9
#       6 ax.imshow(new_img)
#       8 for box in bboxes:
# ----> 9     x, y, w, h = box  # 각 바운딩 박스의 좌표와 너비/높이
#      10     rect = patches.Rectangle((x, y), w, h, linewidth=1, edgecolor='r', facecolor='none')
#      11     ax.add_patch(rect)
#
# ValueError: not enough values to unpack (expected 4, got 2)
